# %%
# ============================================================
# MUST BE FIRST - Before any other imports
# ============================================================
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'  # Fix OMP Error #15

import matplotlib
matplotlib.use('Agg')

os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# ============================================================
# Imports
# ============================================================
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from data_manager import DataManager
from environment import Environment
from ddqn_agent import DDQNAgent
import torch
import time
from datetime import datetime
import random
import gc

# For displaying images in Jupyter
try:
    from IPython.display import display, Image as IPImage
    IN_JUPYTER = True
except ImportError:
    IN_JUPYTER = False

# Initial cleanup
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# GPU Check
print("\n" + "="*80)
print("GPU CHECK")
print("="*80)
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
print("="*80 + "\n")


# ============================================================
# Helper Functions
# ============================================================
def get_instance_type(instance_id: str) -> str:
    instance_id = instance_id.upper()
    if instance_id.startswith('RC'): return 'RC'
    if instance_id.startswith('R'): return 'R'
    if instance_id.startswith('C'): return 'C'
    return 'UNKNOWN'


def cleanup():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()


def show_image(path):
    if IN_JUPYTER and os.path.exists(path):
        display(IPImage(filename=path))


# ============================================================
# CSV Export Functions
# ============================================================
def save_to_csv(episode_rewards, station_losses, portion_losses, 
                epsilon_history, epoch_stats, results_dir):
    """Save all training data to CSV files for easy plotting/analysis."""
    
    print("\nSaving CSV files...")
    
    # 1. Episode-level data (rewards, epsilon per episode)
    episode_df = pd.DataFrame({
        'episode': range(1, len(episode_rewards) + 1),
        'reward': episode_rewards,
        'epsilon': epsilon_history
    })
    episode_path = os.path.join(results_dir, 'episode_data.csv')
    episode_df.to_csv(episode_path, index=False)
    print(f"  [OK] episode_data.csv ({len(episode_df)} rows)")
    
    # 2. Training step losses (station and portion losses per training step)
    max_len = max(len(station_losses), len(portion_losses))
    losses_df = pd.DataFrame({
        'step': range(1, max_len + 1),
        'station_loss': station_losses + [None] * (max_len - len(station_losses)),
        'portion_loss': portion_losses + [None] * (max_len - len(portion_losses))
    })
    losses_path = os.path.join(results_dir, 'losses_data.csv')
    losses_df.to_csv(losses_path, index=False)
    print(f"  [OK] losses_data.csv ({len(losses_df)} rows)")
    
    # 3. Epoch-level statistics
    epoch_df = pd.DataFrame(epoch_stats)
    # Reorder columns for clarity
    cols = ['epoch', 'episode_count', 'mean_reward', 'std_reward', 'min_reward', 'max_reward', 'epsilon', 'time']
    epoch_df = epoch_df[[c for c in cols if c in epoch_df.columns]]
    epoch_path = os.path.join(results_dir, 'epoch_data.csv')
    epoch_df.to_csv(epoch_path, index=False)
    print(f"  [OK] epoch_data.csv ({len(epoch_df)} rows)")
    
    # 4. Combined summary with moving averages (useful for plotting)
    window = min(50, len(episode_rewards) // 5) if len(episode_rewards) > 10 else 1
    
    if window > 1:
        reward_ma = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')
        reward_std = [np.std(episode_rewards[max(0,i-window+1):i+1]) for i in range(len(episode_rewards))]
        
        # Pad MA to match length
        pad = len(episode_rewards) - len(reward_ma)
        reward_ma_padded = [None] * pad + list(reward_ma)
    else:
        reward_ma_padded = episode_rewards
        reward_std = [0] * len(episode_rewards)
    
    summary_df = pd.DataFrame({
        'episode': range(1, len(episode_rewards) + 1),
        'reward': episode_rewards,
        'reward_ma': reward_ma_padded,
        'reward_rolling_std': reward_std,
        'epsilon': epsilon_history
    })
    summary_path = os.path.join(results_dir, 'training_summary.csv')
    summary_df.to_csv(summary_path, index=False)
    print(f"  [OK] training_summary.csv ({len(summary_df)} rows)")
    
    return {
        'episode_data': episode_path,
        'losses_data': losses_path,
        'epoch_data': epoch_path,
        'training_summary': summary_path
    }


# ============================================================
# Plotting Function
# ============================================================
def generate_plots(episode_rewards, station_losses, portion_losses, 
                   epsilon_history, epoch_stats, results_dir, show=True):
    """Generate, save, and optionally display all training plots."""
    
    print("\n" + "="*80)
    print("GENERATING PLOTS")
    print("="*80)
    
    saved = []
    
    plt.rcParams.update({
        'font.size': 11, 'axes.labelsize': 12, 'axes.titlesize': 14,
        'xtick.labelsize': 10, 'ytick.labelsize': 10, 'legend.fontsize': 10,
        'figure.max_open_warning': 0
    })
    
    # ========== 1. REWARD BY EPISODE ==========
    try:
        print("Creating: 1_reward_by_episode.png ...")
        fig, ax = plt.subplots(figsize=(12, 6))
        
        n = len(episode_rewards)
        window = max(1, min(50, n // 5))
        
        if n >= window > 1:
            ma = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')
            ma_x = np.arange(window-1, n)
            ax.plot(ma_x, ma, color='darkblue', lw=3, label=f'{window}-Episode Moving Avg')
            
            std = np.array([np.std(episode_rewards[i-window+1:i+1]) for i in range(window-1, n)])
            ax.fill_between(ma_x, ma-std, ma+std, alpha=0.2, color='darkblue', label='+/- 1 Std')
        else:
            ax.plot(episode_rewards, color='darkblue', lw=2, label='Reward')
        
        ax.set_xlabel('Episode', fontweight='bold')
        ax.set_ylabel('Reward', fontweight='bold')
        ax.set_title('Training Progress by Episode', fontweight='bold')
        ax.legend(loc='lower right')
        ax.grid(True, alpha=0.3, ls='--')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        
        plt.tight_layout()
        path = os.path.join(results_dir, '1_reward_by_episode.png')
        plt.savefig(path, dpi=150, bbox_inches='tight', facecolor='white')
        saved.append(path)
        print(f"  [OK] Saved")
        plt.close(fig)
        if show: show_image(path)
    except Exception as e:
        print(f"  [ERROR] {e}")
        plt.close('all')
    
    cleanup()
    
    # ========== 2. REWARD BY EPOCH (with min-max and std shadows) ==========
    try:
        print("Creating: 2_reward_by_epoch.png ...")
        fig, ax = plt.subplots(figsize=(12, 6))
        
        epochs = np.array([s['epoch'] for s in epoch_stats])
        means = np.array([s['mean_reward'] for s in epoch_stats])
        stds = np.array([s['std_reward'] for s in epoch_stats])
        mins = np.array([s['min_reward'] for s in epoch_stats])
        maxs = np.array([s['max_reward'] for s in epoch_stats])
        
        # Layer 1: Min-Max range (lightest)
        ax.fill_between(epochs, mins, maxs, alpha=0.15, color='skyblue', 
                        label='Min-Max Range', zorder=1)
        
        # Layer 2: Mean +/- Std (medium)
        ax.fill_between(epochs, means-stds, means+stds,
                        alpha=0.3, color='steelblue', label='Mean +/- Std', zorder=2)
        
        # Layer 3: Mean line (bold with markers)
        ax.plot(epochs, means, color='darkblue', lw=3.5, marker='o', 
                markersize=8, markerfacecolor='white', markeredgewidth=2.5, 
                markeredgecolor='darkblue', label='Mean Reward', zorder=3)
        
        # Trend line
        if len(epochs) > 3:
            z = np.polyfit(epochs, means, 2)
            p = np.poly1d(z)
            ax.plot(epochs, p(epochs), color='red', lw=2, ls='--', 
                    alpha=0.7, label='Trend (Poly)', zorder=2)
        
        ax.set_xlabel('Epoch', fontweight='bold')
        ax.set_ylabel('Reward', fontweight='bold')
        ax.set_title('Performance by Epoch', fontweight='bold')
        ax.legend(loc='lower right')
        ax.grid(True, alpha=0.3, ls='--')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        
        plt.tight_layout()
        path = os.path.join(results_dir, '2_reward_by_epoch.png')
        plt.savefig(path, dpi=150, bbox_inches='tight', facecolor='white')
        saved.append(path)
        print(f"  [OK] Saved")
        plt.close(fig)
        if show: show_image(path)
    except Exception as e:
        print(f"  [ERROR] {e}")
        plt.close('all')
    
    cleanup()
    
    # ========== 3. STATION LOSS ==========
    try:
        print("Creating: 3_station_loss.png ...")
        fig, ax = plt.subplots(figsize=(12, 6))
        
        if station_losses:
            n = len(station_losses)
            window = max(1, min(200, n // 5))
            
            if n >= window > 1:
                ma = np.convolve(station_losses, np.ones(window)/window, mode='valid')
                ax.plot(np.arange(window-1, n), ma, color='darkred', lw=2.5, 
                        label=f'Station Loss (MA-{window})')
            else:
                ax.plot(station_losses, color='darkred', lw=1.5, label='Station Loss')
            ax.set_yscale('log')
            ax.legend(loc='upper right')
        else:
            ax.text(0.5, 0.5, 'No data', ha='center', va='center', transform=ax.transAxes)
        
        ax.set_xlabel('Training Step', fontweight='bold')
        ax.set_ylabel('Loss (log)', fontweight='bold')
        ax.set_title('Station Selection Network Loss', fontweight='bold')
        ax.grid(True, alpha=0.3, ls='--')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        
        plt.tight_layout()
        path = os.path.join(results_dir, '3_station_loss.png')
        plt.savefig(path, dpi=150, bbox_inches='tight', facecolor='white')
        saved.append(path)
        print(f"  [OK] Saved")
        plt.close(fig)
        if show: show_image(path)
    except Exception as e:
        print(f"  [ERROR] {e}")
        plt.close('all')
    
    cleanup()
    
    # ========== 4. PORTION LOSS ==========
    try:
        print("Creating: 4_portion_loss.png ...")
        fig, ax = plt.subplots(figsize=(12, 6))
        
        if portion_losses:
            n = len(portion_losses)
            window = max(1, min(200, n // 5))
            
            if n >= window > 1:
                ma = np.convolve(portion_losses, np.ones(window)/window, mode='valid')
                ax.plot(np.arange(window-1, n), ma, color='darkblue', lw=2.5, 
                        label=f'Portion Loss (MA-{window})')
            else:
                ax.plot(portion_losses, color='darkblue', lw=1.5, label='Portion Loss')
            ax.set_yscale('log')
            ax.legend(loc='upper right')
        else:
            ax.text(0.5, 0.5, 'No data', ha='center', va='center', transform=ax.transAxes)
        
        ax.set_xlabel('Training Step', fontweight='bold')
        ax.set_ylabel('Loss (log)', fontweight='bold')
        ax.set_title('Charge Portion Network Loss', fontweight='bold')
        ax.grid(True, alpha=0.3, ls='--')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        
        plt.tight_layout()
        path = os.path.join(results_dir, '4_portion_loss.png')
        plt.savefig(path, dpi=150, bbox_inches='tight', facecolor='white')
        saved.append(path)
        print(f"  [OK] Saved")
        plt.close(fig)
        if show: show_image(path)
    except Exception as e:
        print(f"  [ERROR] {e}")
        plt.close('all')
    
    cleanup()
    
    # ========== 5. EPSILON DECAY ==========
    try:
        print("Creating: 5_epsilon_decay.png ...")
        fig, ax = plt.subplots(figsize=(12, 6))
        
        x = np.arange(len(epsilon_history))
        ax.plot(x, epsilon_history, color='crimson', lw=2.5, label='Epsilon')
        ax.fill_between(x, 0, epsilon_history, alpha=0.25, color='crimson')
        ax.axhline(y=epsilon_history[0], color='gray', ls='--', alpha=0.5, label=f'Start: {epsilon_history[0]:.2f}')
        ax.axhline(y=epsilon_history[-1], color='gray', ls=':', alpha=0.5, label=f'End: {epsilon_history[-1]:.4f}')
        
        ax.set_xlabel('Episode', fontweight='bold')
        ax.set_ylabel('Epsilon', fontweight='bold')
        ax.set_title('Exploration Rate Decay', fontweight='bold')
        ax.set_ylim(0, epsilon_history[0] * 1.05)
        ax.legend(loc='upper right')
        ax.grid(True, alpha=0.3, ls='--')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        
        plt.tight_layout()
        path = os.path.join(results_dir, '5_epsilon_decay.png')
        plt.savefig(path, dpi=150, bbox_inches='tight', facecolor='white')
        saved.append(path)
        print(f"  [OK] Saved")
        plt.close(fig)
        if show: show_image(path)
    except Exception as e:
        print(f"  [ERROR] {e}")
        plt.close('all')
    
    plt.close('all')
    cleanup()
    
    print("-"*80)
    print(f"Saved {len(saved)}/5 plots to: {results_dir}")
    print("="*80 + "\n")
    
    return saved


def regenerate_plots(results_dir, show=True):
    """Regenerate plots from saved CSV data."""
    
    # Try CSV first, fall back to npz
    episode_csv = os.path.join(results_dir, 'episode_data.csv')
    losses_csv = os.path.join(results_dir, 'losses_data.csv')
    epoch_csv = os.path.join(results_dir, 'epoch_data.csv')
    
    if os.path.exists(episode_csv) and os.path.exists(epoch_csv):
        print("Loading from CSV files...")
        
        episode_df = pd.read_csv(episode_csv)
        episode_rewards = episode_df['reward'].tolist()
        epsilon_history = episode_df['epsilon'].tolist()
        
        losses_df = pd.read_csv(losses_csv)
        station_losses = losses_df['station_loss'].dropna().tolist()
        portion_losses = losses_df['portion_loss'].dropna().tolist()
        
        epoch_df = pd.read_csv(epoch_csv)
        epoch_stats = epoch_df.to_dict('records')
        
    else:
        # Fall back to npz
        npz_path = os.path.join(results_dir, 'training_data.npz')
        if not os.path.exists(npz_path):
            print(f"ERROR: No data files found in {results_dir}")
            return []
        
        print(f"Loading from: {npz_path}")
        data = np.load(npz_path, allow_pickle=True)
        
        episode_rewards = list(data['episode_rewards'])
        station_losses = list(data['station_losses'])
        portion_losses = list(data['portion_losses'])
        epsilon_history = list(data['epsilon_history'])
        
        try:
            epoch_stats = list(data['epoch_stats'])
        except:
            epoch_stats = []
            ep_per_epoch = max(1, len(episode_rewards) // 50)
            for i in range(0, len(episode_rewards), ep_per_epoch):
                chunk = episode_rewards[i:i+ep_per_epoch]
                if chunk:
                    epoch_stats.append({
                        'epoch': len(epoch_stats) + 1,
                        'mean_reward': np.mean(chunk), 'std_reward': np.std(chunk),
                        'min_reward': np.min(chunk), 'max_reward': np.max(chunk),
                        'epsilon': epsilon_history[min(i+ep_per_epoch-1, len(epsilon_history)-1)]
                    })
    
    print(f"  Episodes: {len(episode_rewards)}")
    print(f"  Epochs: {len(epoch_stats)}")
    
    return generate_plots(episode_rewards, station_losses, portion_losses,
                          epsilon_history, epoch_stats, results_dir, show)


# ============================================================
# Training Function
# ============================================================
def train(num_epochs=20, learning_rate=0.001, gamma=0.99, epsilon_start=1.0,
          epsilon_decay=0.999, epsilon_min=0.01, batch_size=64, buffer_size=10000,
          target_update_freq=10, device=None, show_plots=True):
    
    device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    results_dir = os.path.join("results", timestamp)
    os.makedirs(results_dir, exist_ok=True)
    
    print("="*80)
    print("DDQN TRAINING - EV CHARGING STATION SELECTION")
    print("="*80)
    print(f"Device: {device} | Epochs: {num_epochs} | Batch: {batch_size}")
    print(f"Results: {results_dir}")
    print("="*80 + "\n")
    
    # Initialize
    start_time = time.time()
    data_manager = DataManager()
    environment = Environment(data_manager)
    
    agent = DDQNAgent(
        learning_rate=learning_rate, gamma=gamma, epsilon=epsilon_start,
        epsilon_decay=epsilon_decay, epsilon_min=epsilon_min, batch_size=batch_size,
        buffer_size=buffer_size, target_update_freq=target_update_freq, device=device
    )
    
    # Categorize instances
    all_instances = data_manager.get_all_instances()
    instances = {'C': {}, 'R': {}, 'RC': {}}
    
    for key, data in all_instances.items():
        itype = get_instance_type(data['instance_id'])
        if itype in instances:
            instances[itype][key] = data
    
    selected = {t: dict(list(v.items())[:10]) for t, v in instances.items()}
    
    print("Selected instances:")
    for t, v in selected.items():
        print(f"  {t}: {[d['instance_id'] for d in v.values()]}")
    print()
    
    # Storage
    episode_rewards, station_losses, portion_losses, epsilon_history, epoch_stats = [], [], [], [], []
    global_ep = 0
    
    # Training loop
    for epoch in range(num_epochs):
        t0 = time.time()
        print("\n" + "="*80)
        print(f"EPOCH {epoch + 1}/{num_epochs}")
        print("="*80)
        
        epoch_instances = [(random.choice(list(selected[t].items())), t) for t in ['C', 'R', 'RC']]
        random.shuffle(epoch_instances)
        
        print("Training:", [f"{t}:{d['instance_id']}" for (_, d), t in epoch_instances])
        
        ep_rewards = []
        
        for (inst_key, inst_data), inst_type in epoch_instances:
            vehicles = data_manager.get_all_vehicles_in_instance(inst_key)
            print(f"\n{inst_type} - {inst_data['instance_id']} ({len(vehicles)} vehicles)")
            
            for v_data in vehicles.values():
                vid = v_data.get('id')
                if not vid:
                    continue
                
                state = environment.reset(inst_key, vid)
                if state is None:
                    continue
                
                reward, steps, done = 0.0, 0, False
                global_ep += 1
                
                while not done and steps < 2:
                    si, pi = agent.select_action(state, training=True)
                    sid = state['station_ids'][si]
                    cp = agent.charge_portions[pi]
                    
                    ns, r, done = environment.step(sid, cp)
                    agent.store_experience(state, si, pi, r, ns, done)
                    
                    if agent.get_buffer_size() >= batch_size:
                        sl, pl = agent.train()
                        station_losses.append(sl)
                        portion_losses.append(pl)
                    
                    state, reward, steps = ns, reward + r, steps + 1
                
                agent.end_episode()
                episode_rewards.append(reward)
                ep_rewards.append(reward)
                epsilon_history.append(agent.get_epsilon())
                
                if global_ep % 5 == 0:
                    cleanup()
        
        # Epoch stats
        stats = {
            'epoch': epoch + 1,
            'mean_reward': np.mean(ep_rewards),
            'std_reward': np.std(ep_rewards),
            'min_reward': np.min(ep_rewards),
            'max_reward': np.max(ep_rewards),
            'epsilon': agent.get_epsilon(),
            'time': time.time() - t0,
            'episode_count': len(ep_rewards)
        }
        epoch_stats.append(stats)
        
        print(f"\n{'-'*80}")
        print(f"EPOCH {epoch+1}: Mean={stats['mean_reward']:.2f} +/- {stats['std_reward']:.2f} | "
              f"[{stats['min_reward']:.2f}, {stats['max_reward']:.2f}] | "
              f"eps={stats['epsilon']:.4f} | {stats['time']/60:.1f}min")
        
        cleanup()
    
    total_time = time.time() - start_time
    
    print("\n" + "="*80)
    print("TRAINING COMPLETE")
    print("="*80)
    print(f"Episodes: {global_ep} | Time: {total_time/60:.1f}min | Final eps: {agent.get_epsilon():.4f}")
    print("="*80 + "\n")
    
    # Save model
    print("Saving...")
    agent.save(os.path.join(results_dir, 'model_final'))
    print("  [OK] Model")
    
    # Save config
    with open(os.path.join(results_dir, 'config.txt'), 'w', encoding='utf-8') as f:
        f.write(f"Timestamp: {timestamp}\n")
        f.write(f"Device: {device}\n")
        f.write(f"Epochs: {num_epochs}\n")
        f.write(f"Learning Rate: {learning_rate}\n")
        f.write(f"Gamma: {gamma}\n")
        f.write(f"Epsilon: {epsilon_start} -> {epsilon_min} (decay={epsilon_decay})\n")
        f.write(f"Batch Size: {batch_size}\n")
        f.write(f"Buffer Size: {buffer_size}\n")
        f.write(f"Target Update Freq: {target_update_freq}\n")
        f.write(f"\nTotal Episodes: {global_ep}\n")
        f.write(f"Total Time: {total_time/60:.1f} min\n")
    print("  [OK] Config")
    
    # Save summary
    with open(os.path.join(results_dir, 'summary.txt'), 'w', encoding='utf-8') as f:
        f.write(f"Total Episodes: {global_ep}\n")
        f.write(f"Total Time: {total_time/60:.1f} min\n")
        f.write(f"Final Epsilon: {agent.get_epsilon():.4f}\n")
        f.write(f"Mean Reward: {np.mean(episode_rewards):.2f} +/- {np.std(episode_rewards):.2f}\n")
        f.write(f"Best Reward: {max(episode_rewards):.2f}\n")
        f.write(f"Worst Reward: {min(episode_rewards):.2f}\n")
        f.write("\n")
        f.write("="*70 + "\n")
        f.write(f"{'Epoch':<8}{'Mean':<12}{'Std':<10}{'Min':<10}{'Max':<10}{'Epsilon':<10}\n")
        f.write("="*70 + "\n")
        for s in epoch_stats:
            f.write(f"{s['epoch']:<8}{s['mean_reward']:<12.2f}{s['std_reward']:<10.2f}"
                   f"{s['min_reward']:<10.2f}{s['max_reward']:<10.2f}{s['epsilon']:<10.4f}\n")
    print("  [OK] Summary")
    
    # Save npz (backup)
    np.savez(os.path.join(results_dir, 'training_data.npz'),
             episode_rewards=episode_rewards, station_losses=station_losses,
             portion_losses=portion_losses, epsilon_history=epsilon_history,
             epoch_stats=epoch_stats)
    print("  [OK] NPZ Data")
    
    # Save CSV files
    csv_paths = save_to_csv(episode_rewards, station_losses, portion_losses,
                            epsilon_history, epoch_stats, results_dir)
    
    cleanup()
    
    # Generate plots
    saved = generate_plots(episode_rewards, station_losses, portion_losses,
                           epsilon_history, epoch_stats, results_dir, show=show_plots)
    
    # Print final summary of saved files
    print("\n" + "="*80)
    print("SAVED FILES:")
    print("="*80)
    print(f"  Model:     model_final/")
    print(f"  Config:    config.txt")
    print(f"  Summary:   summary.txt")
    print(f"  NPZ Data:  training_data.npz")
    print(f"  CSV Files:")
    for name, path in csv_paths.items():
        print(f"             - {os.path.basename(path)}")
    print(f"  Plots:     {len(saved)} PNG files")
    print("="*80 + "\n")
    
    return agent, episode_rewards, epoch_stats, saved, results_dir


# ============================================================
# MAIN
# ============================================================
if __name__ == "__main__":
    config = {
        'num_epochs': 250,
        'learning_rate': 0.001,
        'gamma': 0.99,
        'epsilon_start': 1.0,
        # 'epsilon_decay': 0.99995,
        'epsilon_decay': 0.9999,
        'epsilon_min': 0.01,
        'batch_size': 8,
        'buffer_size': 10000,
        'target_update_freq': 10,
        'device': None,
        'show_plots': True
    }
    
    print("="*80)
    print("CONFIG:", config)
    print("="*80 + "\n")
    
    agent, rewards, epoch_stats, saved, results_dir = train(**config)
    
    print("\n" + "="*80)
    print(f"DONE! Results: {results_dir}")
    print(f"  Plots: {[os.path.basename(p) for p in saved]}")
    print("="*80)
    
    if len(saved) < 5:
        print(f"\nTo regenerate: regenerate_plots('{results_dir}')")
# Out:
# ================================================================================
# GPU CHECK
# ================================================================================
# CUDA: True
# GPU: NVIDIA RTX A5000
# Memory: 25.76 GB
# ================================================================================
#
# ================================================================================
# CONFIG: {'num_epochs': 250, 'learning_rate': 0.001, 'gamma': 0.99, 'epsilon_start': 1.0, 'epsilon_decay': 0.9999, 'epsilon_min': 0.01, 'batch_size': 8, 'buffer_size': 10000, 'target_update_freq': 10, 'device': None, 'show_plots': True}
# ================================================================================
#
# ================================================================================
# DDQN TRAINING - EV CHARGING STATION SELECTION
# ================================================================================
# Device: cuda | Epochs: 250 | Batch: 8
# Results: results\2025-12-18_13-54-23
# ================================================================================
#
# ✓ Loaded dataset with 45 instances
# ✓ Loaded fleet data with 100 vehicles
# ✓ Computed normalization constants
#
# ============================================================
# DDQN Agent Initialization
# ============================================================
# Using device: cuda
# GPU: NVIDIA RTX A5000
# GPU Memory: 25.76 GB
# CUDA Version: 12.1
# ============================================================
#
# Initializing DDQN Architecture on device: cuda
# Using default vehicle input dimension: 7 (x, y, battery, max_battery, time, dist_next, remaining_dist)
# ✓ All networks successfully moved to cuda
# Total trainable parameters: 114,023
# C:\Users\ayoub\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1159: UserWarning: expandable_segments not supported on this platform (Triggered internally at ..\c10/cuda/CUDAAllocatorConfig.h:28.)
#   return t.to(
# Selected instances:
#   C: ['C2_10_3.txt', 'C2_10_5.txt', 'C2_10_8.txt', 'C1_10_6.txt', 'C2_10_2.txt', 'C2_10_7.txt', 'C2_10_1.txt', 'C1_10_10.txt', 'C2_10_10.txt', 'C1_10_2.txt']
#   R: ['R2_10_6.txt', 'R1_10_10.txt', 'R2_10_2.txt', 'R1_10_5.txt', 'R2_10_8.txt', 'R1_10_2.txt', 'R1_10_1.txt', 'R1_10_4.txt', 'R1_10_9.txt', 'R2_10_5.txt']
#   RC: ['RC1_10_5.txt', 'RC2_10_1.txt', 'RC1_10_4.txt', 'RC2_10_2.txt', 'RC2_10_4.txt', 'RC1_10_6.txt', 'RC2_10_5.txt', 'RC2_10_6.txt', 'RC1_10_7.txt', 'RC2_10_7.txt']
#
#
# ================================================================================
# EPOCH 1/250
# ================================================================================
# Training: ['C:C1_10_2.txt', 'RC:RC1_10_5.txt', 'R:R2_10_8.txt']
#
# C - C1_10_2.txt (96 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 1: Mean=-0.55 +/- 0.17 | [-1.04, -0.23] | eps=0.9732 | 1.2min
#
# ================================================================================
# EPOCH 2/250
# ================================================================================
# Training: ['C:C1_10_2.txt', 'RC:RC2_10_2.txt', 'R:R1_10_1.txt']
#
# C - C1_10_2.txt (96 vehicles)
#
# RC - RC2_10_2.txt (97 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 2: Mean=-0.53 +/- 0.17 | [-1.05, -0.24] | eps=0.9471 | 1.2min
#
# ================================================================================
# EPOCH 3/250
# ================================================================================
# Training: ['R:R1_10_1.txt', 'RC:RC1_10_7.txt', 'C:C2_10_1.txt']
#
# R - R1_10_1.txt (98 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# C - C2_10_1.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 3: Mean=-0.53 +/- 0.18 | [-1.12, -0.15] | eps=0.9216 | 1.3min
#
# ================================================================================
# EPOCH 4/250
# ================================================================================
# Training: ['C:C2_10_3.txt', 'R:R1_10_5.txt', 'RC:RC2_10_2.txt']
#
# C - C2_10_3.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC2_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 4: Mean=-0.54 +/- 0.19 | [-1.05, -0.23] | eps=0.8965 | 1.3min
#
# ================================================================================
# EPOCH 5/250
# ================================================================================
# Training: ['C:C2_10_10.txt', 'RC:RC1_10_7.txt', 'R:R1_10_5.txt']
#
# C - C2_10_10.txt (94 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 5: Mean=-0.53 +/- 0.17 | [-1.02, -0.18] | eps=0.8722 | 1.3min
#
# ================================================================================
# EPOCH 6/250
# ================================================================================
# Training: ['R:R2_10_8.txt', 'C:C2_10_3.txt', 'RC:RC1_10_7.txt']
#
# R - R2_10_8.txt (99 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 6: Mean=-0.54 +/- 0.17 | [-1.11, -0.19] | eps=0.8485 | 1.4min
#
# ================================================================================
# EPOCH 7/250
# ================================================================================
# Training: ['C:C2_10_3.txt', 'R:R1_10_5.txt', 'RC:RC2_10_2.txt']
#
# C - C2_10_3.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC2_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 7: Mean=-0.52 +/- 0.18 | [-0.96, -0.19] | eps=0.8253 | 1.4min
#
# ================================================================================
# EPOCH 8/250
# ================================================================================
# Training: ['RC:RC2_10_2.txt', 'C:C1_10_10.txt', 'R:R1_10_9.txt']
#
# RC - RC2_10_2.txt (97 vehicles)
#
# C - C1_10_10.txt (96 vehicles)
#
# R - R1_10_9.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 8: Mean=-0.51 +/- 0.19 | [-1.05, -0.20] | eps=0.8028 | 1.3min
#
# ================================================================================
# EPOCH 9/250
# ================================================================================
# Training: ['RC:RC1_10_5.txt', 'R:R1_10_1.txt', 'C:C2_10_5.txt']
#
# RC - RC1_10_5.txt (98 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# C - C2_10_5.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 9: Mean=-0.51 +/- 0.17 | [-0.96, -0.21] | eps=0.7814 | 1.3min
#
# ================================================================================
# EPOCH 10/250
# ================================================================================
# Training: ['RC:RC2_10_7.txt', 'C:C2_10_3.txt', 'R:R1_10_10.txt']
#
# RC - RC2_10_7.txt (98 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# R - R1_10_10.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 10: Mean=-0.51 +/- 0.19 | [-1.02, -0.19] | eps=0.7601 | 1.4min
#
# ================================================================================
# EPOCH 11/250
# ================================================================================
# Training: ['RC:RC2_10_2.txt', 'R:R2_10_6.txt', 'C:C1_10_10.txt']
#
# RC - RC2_10_2.txt (97 vehicles)
#
# R - R2_10_6.txt (99 vehicles)
#
# C - C1_10_10.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 11: Mean=-0.50 +/- 0.18 | [-1.06, -0.18] | eps=0.7395 | 1.3min
#
# ================================================================================
# EPOCH 12/250
# ================================================================================
# Training: ['C:C2_10_2.txt', 'R:R1_10_1.txt', 'RC:RC2_10_5.txt']
#
# C - C2_10_2.txt (98 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# RC - RC2_10_5.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 12: Mean=-0.52 +/- 0.18 | [-1.06, -0.22] | eps=0.7199 | 1.3min
#
# ================================================================================
# EPOCH 13/250
# ================================================================================
# Training: ['RC:RC2_10_5.txt', 'C:C2_10_10.txt', 'R:R2_10_8.txt']
#
# RC - RC2_10_5.txt (97 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 13: Mean=-0.51 +/- 0.19 | [-1.12, -0.19] | eps=0.7012 | 1.3min
#
# ================================================================================
# EPOCH 14/250
# ================================================================================
# Training: ['R:R1_10_2.txt', 'C:C2_10_5.txt', 'RC:RC2_10_1.txt']
#
# R - R1_10_2.txt (97 vehicles)
#
# C - C2_10_5.txt (96 vehicles)
#
# RC - RC2_10_1.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 14: Mean=-0.51 +/- 0.18 | [-1.01, -0.18] | eps=0.6826 | 1.3min
#
# ================================================================================
# EPOCH 15/250
# ================================================================================
# Training: ['RC:RC2_10_6.txt', 'C:C2_10_2.txt', 'R:R2_10_8.txt']
#
# RC - RC2_10_6.txt (97 vehicles)
#
# C - C2_10_2.txt (98 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 15: Mean=-0.50 +/- 0.18 | [-0.94, -0.19] | eps=0.6644 | 1.3min
#
# ================================================================================
# EPOCH 16/250
# ================================================================================
# Training: ['C:C1_10_2.txt', 'RC:RC2_10_6.txt', 'R:R1_10_2.txt']
#
# C - C1_10_2.txt (96 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 16: Mean=-0.49 +/- 0.18 | [-1.21, -0.20] | eps=0.6467 | 1.3min
#
# ================================================================================
# EPOCH 17/250
# ================================================================================
# Training: ['C:C2_10_2.txt', 'R:R1_10_1.txt', 'RC:RC2_10_4.txt']
#
# C - C2_10_2.txt (98 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 17: Mean=-0.48 +/- 0.18 | [-1.05, -0.20] | eps=0.6294 | 1.3min
#
# ================================================================================
# EPOCH 18/250
# ================================================================================
# Training: ['RC:RC1_10_7.txt', 'C:C2_10_10.txt', 'R:R2_10_5.txt']
#
# RC - RC1_10_7.txt (98 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R2_10_5.txt (100 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 18: Mean=-0.49 +/- 0.19 | [-1.09, -0.16] | eps=0.6128 | 1.3min
#
# ================================================================================
# EPOCH 19/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'RC:RC2_10_7.txt', 'R:R1_10_5.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 19: Mean=-0.48 +/- 0.17 | [-1.03, -0.18] | eps=0.5959 | 1.3min
#
# ================================================================================
# EPOCH 20/250
# ================================================================================
# Training: ['C:C2_10_8.txt', 'RC:RC1_10_4.txt', 'R:R1_10_5.txt']
#
# C - C2_10_8.txt (96 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 20: Mean=-0.47 +/- 0.19 | [-1.02, -0.20] | eps=0.5799 | 1.3min
#
# ================================================================================
# EPOCH 21/250
# ================================================================================
# Training: ['R:R1_10_10.txt', 'C:C2_10_3.txt', 'RC:RC2_10_7.txt']
#
# R - R1_10_10.txt (99 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 21: Mean=-0.48 +/- 0.17 | [-1.10, -0.18] | eps=0.5641 | 1.4min
#
# ================================================================================
# EPOCH 22/250
# ================================================================================
# Training: ['C:C2_10_1.txt', 'RC:RC1_10_4.txt', 'R:R1_10_9.txt']
#
# C - C2_10_1.txt (96 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# R - R1_10_9.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 22: Mean=-0.47 +/- 0.16 | [-0.91, -0.18] | eps=0.5490 | 1.3min
#
# ================================================================================
# EPOCH 23/250
# ================================================================================
# Training: ['C:C1_10_2.txt', 'RC:RC1_10_7.txt', 'R:R1_10_5.txt']
#
# C - C1_10_2.txt (96 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 23: Mean=-0.44 +/- 0.17 | [-0.93, -0.16] | eps=0.5339 | 1.3min
#
# ================================================================================
# EPOCH 24/250
# ================================================================================
# Training: ['C:C2_10_10.txt', 'R:R1_10_5.txt', 'RC:RC2_10_6.txt']
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 24: Mean=-0.47 +/- 0.18 | [-0.93, -0.17] | eps=0.5197 | 1.3min
#
# ================================================================================
# EPOCH 25/250
# ================================================================================
# Training: ['R:R2_10_5.txt', 'C:C2_10_7.txt', 'RC:RC2_10_2.txt']
#
# R - R2_10_5.txt (100 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC2_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 25: Mean=-0.47 +/- 0.19 | [-1.02, -0.20] | eps=0.5062 | 1.3min
#
# ================================================================================
# EPOCH 26/250
# ================================================================================
# Training: ['R:R2_10_5.txt', 'C:C1_10_2.txt', 'RC:RC2_10_1.txt']
#
# R - R2_10_5.txt (100 vehicles)
#
# C - C1_10_2.txt (96 vehicles)
#
# RC - RC2_10_1.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 26: Mean=-0.47 +/- 0.18 | [-0.90, -0.18] | eps=0.4928 | 1.3min
#
# ================================================================================
# EPOCH 27/250
# ================================================================================
# Training: ['RC:RC2_10_4.txt', 'R:R1_10_2.txt', 'C:C1_10_10.txt']
#
# RC - RC2_10_4.txt (98 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# C - C1_10_10.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 27: Mean=-0.44 +/- 0.17 | [-1.10, -0.18] | eps=0.4794 | 1.3min
#
# ================================================================================
# EPOCH 28/250
# ================================================================================
# Training: ['C:C2_10_1.txt', 'RC:RC2_10_2.txt', 'R:R1_10_1.txt']
#
# C - C2_10_1.txt (96 vehicles)
#
# RC - RC2_10_2.txt (97 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 28: Mean=-0.47 +/- 0.20 | [-0.94, -0.15] | eps=0.4667 | 1.3min
#
# ================================================================================
# EPOCH 29/250
# ================================================================================
# Training: ['R:R2_10_5.txt', 'RC:RC1_10_5.txt', 'C:C1_10_2.txt']
#
# R - R2_10_5.txt (100 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# C - C1_10_2.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 29: Mean=-0.45 +/- 0.17 | [-0.97, -0.19] | eps=0.4543 | 1.3min
#
# ================================================================================
# EPOCH 30/250
# ================================================================================
# Training: ['R:R1_10_2.txt', 'RC:RC1_10_5.txt', 'C:C2_10_7.txt']
#
# R - R1_10_2.txt (97 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 30: Mean=-0.46 +/- 0.18 | [-0.92, -0.20] | eps=0.4423 | 1.3min
#
# ================================================================================
# EPOCH 31/250
# ================================================================================
# Training: ['R:R2_10_2.txt', 'RC:RC2_10_1.txt', 'C:C2_10_5.txt']
#
# R - R2_10_2.txt (99 vehicles)
#
# RC - RC2_10_1.txt (97 vehicles)
#
# C - C2_10_5.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 31: Mean=-0.46 +/- 0.18 | [-0.99, -0.19] | eps=0.4305 | 1.4min
#
# ================================================================================
# EPOCH 32/250
# ================================================================================
# Training: ['R:R2_10_5.txt', 'C:C2_10_10.txt', 'RC:RC2_10_6.txt']
#
# R - R2_10_5.txt (100 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 32: Mean=-0.45 +/- 0.18 | [-1.10, -0.21] | eps=0.4194 | 1.3min
#
# ================================================================================
# EPOCH 33/250
# ================================================================================
# Training: ['RC:RC2_10_4.txt', 'C:C2_10_10.txt', 'R:R1_10_1.txt']
#
# RC - RC2_10_4.txt (98 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 33: Mean=-0.43 +/- 0.18 | [-0.95, -0.20] | eps=0.4083 | 1.3min
#
# ================================================================================
# EPOCH 34/250
# ================================================================================
# Training: ['RC:RC2_10_5.txt', 'C:C2_10_8.txt', 'R:R2_10_6.txt']
#
# RC - RC2_10_5.txt (97 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# R - R2_10_6.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 34: Mean=-0.44 +/- 0.18 | [-0.97, -0.19] | eps=0.3976 | 1.3min
#
# ================================================================================
# EPOCH 35/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'R:R1_10_4.txt', 'RC:RC2_10_2.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# R - R1_10_4.txt (98 vehicles)
#
# RC - RC2_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 35: Mean=-0.42 +/- 0.18 | [-1.00, -0.21] | eps=0.3868 | 1.3min
#
# ================================================================================
# EPOCH 36/250
# ================================================================================
# Training: ['C:C2_10_7.txt', 'RC:RC1_10_6.txt', 'R:R1_10_9.txt']
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# R - R1_10_9.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 36: Mean=-0.42 +/- 0.17 | [-0.86, -0.16] | eps=0.3765 | 1.3min
#
# ================================================================================
# EPOCH 37/250
# ================================================================================
# Training: ['RC:RC2_10_7.txt', 'R:R2_10_5.txt', 'C:C2_10_1.txt']
#
# RC - RC2_10_7.txt (98 vehicles)
#
# R - R2_10_5.txt (100 vehicles)
#
# C - C2_10_1.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 37: Mean=-0.48 +/- 0.18 | [-1.02, -0.18] | eps=0.3666 | 1.4min
#
# ================================================================================
# EPOCH 38/250
# ================================================================================
# Training: ['RC:RC2_10_4.txt', 'C:C1_10_10.txt', 'R:R2_10_2.txt']
#
# RC - RC2_10_4.txt (98 vehicles)
#
# C - C1_10_10.txt (96 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 38: Mean=-0.41 +/- 0.15 | [-1.06, -0.21] | eps=0.3566 | 1.3min
#
# ================================================================================
# EPOCH 39/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'RC:RC1_10_6.txt', 'R:R2_10_8.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 39: Mean=-0.42 +/- 0.17 | [-1.08, -0.21] | eps=0.3470 | 1.3min
#
# ================================================================================
# EPOCH 40/250
# ================================================================================
# Training: ['C:C2_10_3.txt', 'R:R1_10_10.txt', 'RC:RC2_10_5.txt']
#
# C - C2_10_3.txt (98 vehicles)
#
# R - R1_10_10.txt (99 vehicles)
#
# RC - RC2_10_5.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 40: Mean=-0.44 +/- 0.18 | [-1.02, -0.19] | eps=0.3376 | 1.4min
#
# ================================================================================
# EPOCH 41/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'RC:RC2_10_4.txt', 'R:R2_10_2.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 41: Mean=-0.43 +/- 0.17 | [-0.96, -0.18] | eps=0.3285 | 1.3min
#
# ================================================================================
# EPOCH 42/250
# ================================================================================
# Training: ['RC:RC2_10_1.txt', 'C:C2_10_3.txt', 'R:R1_10_10.txt']
#
# RC - RC2_10_1.txt (97 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# R - R1_10_10.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 42: Mean=-0.43 +/- 0.18 | [-1.07, -0.20] | eps=0.3195 | 1.4min
#
# ================================================================================
# EPOCH 43/250
# ================================================================================
# Training: ['C:C2_10_1.txt', 'R:R1_10_5.txt', 'RC:RC1_10_4.txt']
#
# C - C2_10_1.txt (96 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 43: Mean=-0.44 +/- 0.16 | [-0.90, -0.16] | eps=0.3109 | 1.3min
#
# ================================================================================
# EPOCH 44/250
# ================================================================================
# Training: ['R:R1_10_5.txt', 'RC:RC1_10_6.txt', 'C:C2_10_7.txt']
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 44: Mean=-0.44 +/- 0.17 | [-0.98, -0.16] | eps=0.3026 | 1.3min
#
# ================================================================================
# EPOCH 45/250
# ================================================================================
# Training: ['R:R1_10_9.txt', 'RC:RC1_10_5.txt', 'C:C2_10_5.txt']
#
# R - R1_10_9.txt (99 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# C - C2_10_5.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 45: Mean=-0.40 +/- 0.16 | [-0.88, -0.18] | eps=0.2945 | 1.3min
#
# ================================================================================
# EPOCH 46/250
# ================================================================================
# Training: ['R:R1_10_9.txt', 'C:C2_10_8.txt', 'RC:RC2_10_6.txt']
#
# R - R1_10_9.txt (99 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 46: Mean=-0.43 +/- 0.19 | [-1.04, -0.17] | eps=0.2867 | 1.3min
#
# ================================================================================
# EPOCH 47/250
# ================================================================================
# Training: ['C:C2_10_10.txt', 'R:R2_10_2.txt', 'RC:RC2_10_4.txt']
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 47: Mean=-0.44 +/- 0.17 | [-0.91, -0.18] | eps=0.2791 | 1.4min
#
# ================================================================================
# EPOCH 48/250
# ================================================================================
# Training: ['C:C2_10_5.txt', 'R:R2_10_2.txt', 'RC:RC2_10_6.txt']
#
# C - C2_10_5.txt (96 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 48: Mean=-0.43 +/- 0.16 | [-0.82, -0.17] | eps=0.2717 | 1.4min
#
# ================================================================================
# EPOCH 49/250
# ================================================================================
# Training: ['C:C2_10_10.txt', 'R:R2_10_2.txt', 'RC:RC2_10_5.txt']
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# RC - RC2_10_5.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 49: Mean=-0.44 +/- 0.17 | [-0.98, -0.20] | eps=0.2646 | 1.4min
#
# ================================================================================
# EPOCH 50/250
# ================================================================================
# Training: ['R:R1_10_10.txt', 'RC:RC2_10_4.txt', 'C:C1_10_2.txt']
#
# R - R1_10_10.txt (99 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# C - C1_10_2.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 50: Mean=-0.39 +/- 0.17 | [-0.86, -0.18] | eps=0.2574 | 1.3min
#
# ================================================================================
# EPOCH 51/250
# ================================================================================
# Training: ['R:R1_10_4.txt', 'C:C1_10_10.txt', 'RC:RC2_10_7.txt']
#
# R - R1_10_4.txt (98 vehicles)
#
# C - C1_10_10.txt (96 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 51: Mean=-0.41 +/- 0.17 | [-0.90, -0.18] | eps=0.2504 | 1.3min
#
# ================================================================================
# EPOCH 52/250
# ================================================================================
# Training: ['R:R2_10_8.txt', 'RC:RC1_10_4.txt', 'C:C2_10_10.txt']
#
# R - R2_10_8.txt (99 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 52: Mean=-0.42 +/- 0.16 | [-0.83, -0.14] | eps=0.2438 | 1.3min
#
# ================================================================================
# EPOCH 53/250
# ================================================================================
# Training: ['RC:RC1_10_5.txt', 'C:C1_10_10.txt', 'R:R1_10_1.txt']
#
# RC - RC1_10_5.txt (98 vehicles)
#
# C - C1_10_10.txt (96 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 53: Mean=-0.39 +/- 0.16 | [-0.97, -0.15] | eps=0.2371 | 1.2min
#
# ================================================================================
# EPOCH 54/250
# ================================================================================
# Training: ['R:R1_10_9.txt', 'RC:RC1_10_6.txt', 'C:C2_10_3.txt']
#
# R - R1_10_9.txt (99 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 54: Mean=-0.41 +/- 0.17 | [-0.88, -0.16] | eps=0.2307 | 1.3min
#
# ================================================================================
# EPOCH 55/250
# ================================================================================
# Training: ['RC:RC1_10_7.txt', 'R:R1_10_10.txt', 'C:C1_10_6.txt']
#
# RC - RC1_10_7.txt (98 vehicles)
#
# R - R1_10_10.txt (99 vehicles)
#
# C - C1_10_6.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 55: Mean=-0.38 +/- 0.17 | [-1.05, -0.16] | eps=0.2243 | 1.3min
#
# ================================================================================
# EPOCH 56/250
# ================================================================================
# Training: ['C:C2_10_5.txt', 'RC:RC1_10_7.txt', 'R:R2_10_5.txt']
#
# C - C2_10_5.txt (96 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# R - R2_10_5.txt (100 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 56: Mean=-0.41 +/- 0.17 | [-0.93, -0.16] | eps=0.2184 | 1.3min
#
# ================================================================================
# EPOCH 57/250
# ================================================================================
# Training: ['RC:RC2_10_5.txt', 'C:C2_10_7.txt', 'R:R1_10_5.txt']
#
# RC - RC2_10_5.txt (97 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 57: Mean=-0.41 +/- 0.16 | [-0.87, -0.16] | eps=0.2126 | 1.3min
#
# ================================================================================
# EPOCH 58/250
# ================================================================================
# Training: ['C:C2_10_5.txt', 'RC:RC2_10_1.txt', 'R:R1_10_2.txt']
#
# C - C2_10_5.txt (96 vehicles)
#
# RC - RC2_10_1.txt (97 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 58: Mean=-0.39 +/- 0.16 | [-0.95, -0.19] | eps=0.2070 | 1.3min
#
# ================================================================================
# EPOCH 59/250
# ================================================================================
# Training: ['C:C2_10_8.txt', 'RC:RC1_10_6.txt', 'R:R2_10_5.txt']
#
# C - C2_10_8.txt (96 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# R - R2_10_5.txt (100 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 59: Mean=-0.39 +/- 0.17 | [-0.88, -0.16] | eps=0.2016 | 1.3min
#
# ================================================================================
# EPOCH 60/250
# ================================================================================
# Training: ['RC:RC1_10_6.txt', 'C:C1_10_2.txt', 'R:R2_10_8.txt']
#
# RC - RC1_10_6.txt (98 vehicles)
#
# C - C1_10_2.txt (96 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 60: Mean=-0.38 +/- 0.15 | [-0.84, -0.14] | eps=0.1962 | 1.2min
#
# ================================================================================
# EPOCH 61/250
# ================================================================================
# Training: ['C:C2_10_1.txt', 'RC:RC2_10_5.txt', 'R:R1_10_1.txt']
#
# C - C2_10_1.txt (96 vehicles)
#
# RC - RC2_10_5.txt (97 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 61: Mean=-0.40 +/- 0.17 | [-0.91, -0.15] | eps=0.1910 | 1.3min
#
# ================================================================================
# EPOCH 62/250
# ================================================================================
# Training: ['C:C2_10_7.txt', 'RC:RC1_10_6.txt', 'R:R2_10_2.txt']
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 62: Mean=-0.41 +/- 0.16 | [-0.82, -0.16] | eps=0.1860 | 1.3min
#
# ================================================================================
# EPOCH 63/250
# ================================================================================
# Training: ['RC:RC2_10_1.txt', 'R:R1_10_10.txt', 'C:C1_10_6.txt']
#
# RC - RC2_10_1.txt (97 vehicles)
#
# R - R1_10_10.txt (99 vehicles)
#
# C - C1_10_6.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 63: Mean=-0.36 +/- 0.17 | [-0.99, -0.18] | eps=0.1809 | 1.3min
#
# ================================================================================
# EPOCH 64/250
# ================================================================================
# Training: ['RC:RC2_10_6.txt', 'C:C2_10_10.txt', 'R:R1_10_10.txt']
#
# RC - RC2_10_6.txt (97 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R1_10_10.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 64: Mean=-0.40 +/- 0.17 | [-0.89, -0.17] | eps=0.1761 | 1.3min
#
# ================================================================================
# EPOCH 65/250
# ================================================================================
# Training: ['C:C2_10_7.txt', 'RC:RC2_10_5.txt', 'R:R1_10_5.txt']
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC2_10_5.txt (97 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 65: Mean=-0.40 +/- 0.16 | [-0.85, -0.18] | eps=0.1715 | 1.3min
#
# ================================================================================
# EPOCH 66/250
# ================================================================================
# Training: ['R:R1_10_2.txt', 'C:C1_10_2.txt', 'RC:RC1_10_7.txt']
#
# R - R1_10_2.txt (97 vehicles)
#
# C - C1_10_2.txt (96 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 66: Mean=-0.36 +/- 0.16 | [-0.88, -0.16] | eps=0.1668 | 1.2min
#
# ================================================================================
# EPOCH 67/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'RC:RC2_10_1.txt', 'R:R1_10_4.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# RC - RC2_10_1.txt (97 vehicles)
#
# R - R1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 67: Mean=-0.37 +/- 0.17 | [-0.91, -0.18] | eps=0.1623 | 1.3min
#
# ================================================================================
# EPOCH 68/250
# ================================================================================
# Training: ['RC:RC1_10_6.txt', 'R:R1_10_2.txt', 'C:C2_10_7.txt']
#
# RC - RC1_10_6.txt (98 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 68: Mean=-0.37 +/- 0.14 | [-0.90, -0.16] | eps=0.1580 | 1.2min
#
# ================================================================================
# EPOCH 69/250
# ================================================================================
# Training: ['R:R2_10_6.txt', 'C:C2_10_8.txt', 'RC:RC2_10_6.txt']
#
# R - R2_10_6.txt (99 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 69: Mean=-0.40 +/- 0.17 | [-0.95, -0.17] | eps=0.1538 | 1.3min
#
# ================================================================================
# EPOCH 70/250
# ================================================================================
# Training: ['C:C2_10_1.txt', 'R:R1_10_10.txt', 'RC:RC1_10_5.txt']
#
# C - C2_10_1.txt (96 vehicles)
#
# R - R1_10_10.txt (99 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 70: Mean=-0.41 +/- 0.19 | [-0.96, -0.19] | eps=0.1497 | 1.3min
#
# ================================================================================
# EPOCH 71/250
# ================================================================================
# Training: ['C:C2_10_5.txt', 'R:R2_10_6.txt', 'RC:RC1_10_5.txt']
#
# C - C2_10_5.txt (96 vehicles)
#
# R - R2_10_6.txt (99 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 71: Mean=-0.38 +/- 0.17 | [-0.87, -0.17] | eps=0.1458 | 1.3min
#
# ================================================================================
# EPOCH 72/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'R:R1_10_5.txt', 'RC:RC2_10_6.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 72: Mean=-0.37 +/- 0.14 | [-0.75, -0.16] | eps=0.1418 | 1.3min
#
# ================================================================================
# EPOCH 73/250
# ================================================================================
# Training: ['RC:RC2_10_1.txt', 'C:C2_10_1.txt', 'R:R1_10_1.txt']
#
# RC - RC2_10_1.txt (97 vehicles)
#
# C - C2_10_1.txt (96 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 73: Mean=-0.40 +/- 0.17 | [-0.88, -0.19] | eps=0.1380 | 1.3min
#
# ================================================================================
# EPOCH 74/250
# ================================================================================
# Training: ['C:C2_10_3.txt', 'R:R2_10_2.txt', 'RC:RC2_10_6.txt']
#
# C - C2_10_3.txt (98 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 74: Mean=-0.43 +/- 0.18 | [-0.92, -0.19] | eps=0.1343 | 1.4min
#
# ================================================================================
# EPOCH 75/250
# ================================================================================
# Training: ['C:C2_10_5.txt', 'R:R2_10_8.txt', 'RC:RC2_10_2.txt']
#
# C - C2_10_5.txt (96 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# RC - RC2_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 75: Mean=-0.39 +/- 0.17 | [-0.91, -0.14] | eps=0.1308 | 1.3min
#
# ================================================================================
# EPOCH 76/250
# ================================================================================
# Training: ['R:R1_10_9.txt', 'C:C2_10_8.txt', 'RC:RC1_10_6.txt']
#
# R - R1_10_9.txt (99 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 76: Mean=-0.38 +/- 0.17 | [-1.01, -0.16] | eps=0.1273 | 1.3min
#
# ================================================================================
# EPOCH 77/250
# ================================================================================
# Training: ['C:C2_10_7.txt', 'R:R2_10_8.txt', 'RC:RC1_10_6.txt']
#
# C - C2_10_7.txt (95 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 77: Mean=-0.37 +/- 0.15 | [-0.86, -0.14] | eps=0.1239 | 1.3min
#
# ================================================================================
# EPOCH 78/250
# ================================================================================
# Training: ['R:R1_10_1.txt', 'C:C2_10_2.txt', 'RC:RC1_10_5.txt']
#
# R - R1_10_1.txt (98 vehicles)
#
# C - C2_10_2.txt (98 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 78: Mean=-0.38 +/- 0.15 | [-0.82, -0.20] | eps=0.1206 | 1.3min
#
# ================================================================================
# EPOCH 79/250
# ================================================================================
# Training: ['R:R1_10_2.txt', 'RC:RC2_10_7.txt', 'C:C2_10_7.txt']
#
# R - R1_10_2.txt (97 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 79: Mean=-0.42 +/- 0.16 | [-0.81, -0.19] | eps=0.1174 | 1.3min
#
# ================================================================================
# EPOCH 80/250
# ================================================================================
# Training: ['C:C2_10_8.txt', 'R:R1_10_2.txt', 'RC:RC1_10_4.txt']
#
# C - C2_10_8.txt (96 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 80: Mean=-0.39 +/- 0.17 | [-1.04, -0.19] | eps=0.1142 | 1.3min
#
# ================================================================================
# EPOCH 81/250
# ================================================================================
# Training: ['C:C2_10_7.txt', 'RC:RC2_10_4.txt', 'R:R1_10_5.txt']
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 81: Mean=-0.38 +/- 0.15 | [-0.84, -0.17] | eps=0.1112 | 1.3min
#
# ================================================================================
# EPOCH 82/250
# ================================================================================
# Training: ['RC:RC2_10_5.txt', 'R:R2_10_2.txt', 'C:C2_10_7.txt']
#
# RC - RC2_10_5.txt (97 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 82: Mean=-0.41 +/- 0.16 | [-0.80, -0.18] | eps=0.1083 | 1.3min
#
# ================================================================================
# EPOCH 83/250
# ================================================================================
# Training: ['RC:RC2_10_1.txt', 'R:R2_10_8.txt', 'C:C2_10_8.txt']
#
# RC - RC2_10_1.txt (97 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 83: Mean=-0.40 +/- 0.16 | [-0.87, -0.20] | eps=0.1054 | 1.3min
#
# ================================================================================
# EPOCH 84/250
# ================================================================================
# Training: ['RC:RC2_10_7.txt', 'R:R1_10_5.txt', 'C:C2_10_5.txt']
#
# RC - RC2_10_7.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# C - C2_10_5.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 84: Mean=-0.41 +/- 0.16 | [-0.86, -0.16] | eps=0.1026 | 1.3min
#
# ================================================================================
# EPOCH 85/250
# ================================================================================
# Training: ['R:R2_10_6.txt', 'RC:RC1_10_4.txt', 'C:C1_10_6.txt']
#
# R - R2_10_6.txt (99 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# C - C1_10_6.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 85: Mean=-0.38 +/- 0.15 | [-0.86, -0.17] | eps=0.0998 | 1.3min
#
# ================================================================================
# EPOCH 86/250
# ================================================================================
# Training: ['R:R1_10_5.txt', 'C:C2_10_10.txt', 'RC:RC1_10_5.txt']
#
# R - R1_10_5.txt (99 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 86: Mean=-0.38 +/- 0.15 | [-0.84, -0.18] | eps=0.0971 | 1.3min
#
# ================================================================================
# EPOCH 87/250
# ================================================================================
# Training: ['C:C2_10_7.txt', 'RC:RC2_10_4.txt', 'R:R2_10_2.txt']
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# R - R2_10_2.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 87: Mean=-0.39 +/- 0.15 | [-0.80, -0.18] | eps=0.0945 | 1.3min
#
# ================================================================================
# EPOCH 88/250
# ================================================================================
# Training: ['C:C2_10_2.txt', 'R:R1_10_5.txt', 'RC:RC1_10_7.txt']
#
# C - C2_10_2.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 88: Mean=-0.38 +/- 0.18 | [-0.86, -0.16] | eps=0.0919 | 1.3min
#
# ================================================================================
# EPOCH 89/250
# ================================================================================
# Training: ['R:R1_10_2.txt', 'C:C2_10_7.txt', 'RC:RC1_10_5.txt']
#
# R - R1_10_2.txt (97 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC1_10_5.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 89: Mean=-0.39 +/- 0.15 | [-0.82, -0.19] | eps=0.0895 | 1.3min
#
# ================================================================================
# EPOCH 90/250
# ================================================================================
# Training: ['RC:RC2_10_2.txt', 'R:R1_10_5.txt', 'C:C1_10_10.txt']
#
# RC - RC2_10_2.txt (97 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# C - C1_10_10.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 90: Mean=-0.38 +/- 0.15 | [-0.97, -0.20] | eps=0.0870 | 1.3min
#
# ================================================================================
# EPOCH 91/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'R:R2_10_5.txt', 'RC:RC1_10_7.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# R - R2_10_5.txt (100 vehicles)
#
# RC - RC1_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 91: Mean=-0.34 +/- 0.17 | [-0.91, -0.16] | eps=0.0847 | 1.3min
#
# ================================================================================
# EPOCH 92/250
# ================================================================================
# Training: ['RC:RC2_10_7.txt', 'R:R1_10_5.txt', 'C:C2_10_8.txt']
#
# RC - RC2_10_7.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 92: Mean=-0.39 +/- 0.16 | [-0.87, -0.16] | eps=0.0824 | 1.3min
#
# ================================================================================
# EPOCH 93/250
# ================================================================================
# Training: ['R:R1_10_5.txt', 'C:C2_10_7.txt', 'RC:RC2_10_4.txt']
#
# R - R1_10_5.txt (99 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 93: Mean=-0.37 +/- 0.16 | [-0.88, -0.16] | eps=0.0802 | 1.3min
#
# ================================================================================
# EPOCH 94/250
# ================================================================================
# Training: ['RC:RC2_10_7.txt', 'R:R1_10_2.txt', 'C:C1_10_6.txt']
#
# RC - RC2_10_7.txt (98 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# ...
#
# R - R1_10_10.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 222: Mean=-0.36 +/- 0.17 | [-0.79, -0.18] | eps=0.0100 | 1.7min
#
# ================================================================================
# EPOCH 223/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'R:R1_10_5.txt', 'RC:RC1_10_4.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 223: Mean=-0.34 +/- 0.14 | [-0.82, -0.16] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 224/250
# ================================================================================
# Training: ['R:R2_10_5.txt', 'RC:RC2_10_4.txt', 'C:C2_10_2.txt']
#
# R - R2_10_5.txt (100 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# C - C2_10_2.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 224: Mean=-0.37 +/- 0.16 | [-0.88, -0.18] | eps=0.0100 | 1.7min
#
# ================================================================================
# EPOCH 225/250
# ================================================================================
# Training: ['RC:RC2_10_4.txt', 'R:R2_10_8.txt', 'C:C2_10_8.txt']
#
# RC - RC2_10_4.txt (98 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 225: Mean=-0.36 +/- 0.16 | [-0.87, -0.14] | eps=0.0100 | 1.7min
#
# ================================================================================
# EPOCH 226/250
# ================================================================================
# Training: ['RC:RC2_10_2.txt', 'C:C2_10_5.txt', 'R:R1_10_9.txt']
#
# RC - RC2_10_2.txt (97 vehicles)
#
# C - C2_10_5.txt (96 vehicles)
#
# R - R1_10_9.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 226: Mean=-0.36 +/- 0.15 | [-0.82, -0.18] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 227/250
# ================================================================================
# Training: ['RC:RC2_10_6.txt', 'C:C2_10_3.txt', 'R:R1_10_2.txt']
#
# RC - RC2_10_6.txt (97 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 227: Mean=-0.36 +/- 0.15 | [-0.82, -0.17] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 228/250
# ================================================================================
# Training: ['R:R2_10_8.txt', 'C:C2_10_1.txt', 'RC:RC1_10_4.txt']
#
# R - R2_10_8.txt (99 vehicles)
#
# C - C2_10_1.txt (96 vehicles)
#
# RC - RC1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 228: Mean=-0.38 +/- 0.16 | [-0.84, -0.14] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 229/250
# ================================================================================
# Training: ['C:C1_10_6.txt', 'R:R1_10_4.txt', 'RC:RC2_10_6.txt']
#
# C - C1_10_6.txt (96 vehicles)
#
# R - R1_10_4.txt (98 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 229: Mean=-0.35 +/- 0.15 | [-0.92, -0.21] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 230/250
# ================================================================================
# Training: ['RC:RC1_10_4.txt', 'C:C2_10_8.txt', 'R:R1_10_1.txt']
#
# RC - RC1_10_4.txt (98 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# R - R1_10_1.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 230: Mean=-0.35 +/- 0.15 | [-0.83, -0.20] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 231/250
# ================================================================================
# Training: ['RC:RC2_10_4.txt', 'C:C2_10_1.txt', 'R:R2_10_8.txt']
#
# RC - RC2_10_4.txt (98 vehicles)
#
# C - C2_10_1.txt (96 vehicles)
#
# R - R2_10_8.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 231: Mean=-0.36 +/- 0.17 | [-0.92, -0.14] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 232/250
# ================================================================================
# Training: ['R:R1_10_9.txt', 'C:C2_10_8.txt', 'RC:RC2_10_7.txt']
#
# R - R1_10_9.txt (99 vehicles)
#
# C - C2_10_8.txt (96 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 232: Mean=-0.38 +/- 0.18 | [-0.89, -0.18] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 233/250
# ================================================================================
# Training: ['RC:RC2_10_1.txt', 'C:C2_10_10.txt', 'R:R2_10_6.txt']
#
# RC - RC2_10_1.txt (97 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# R - R2_10_6.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 233: Mean=-0.41 +/- 0.20 | [-0.98, -0.18] | eps=0.0100 | 1.7min
#
# ================================================================================
# EPOCH 234/250
# ================================================================================
# Training: ['RC:RC1_10_7.txt', 'C:C2_10_1.txt', 'R:R1_10_4.txt']
#
# RC - RC1_10_7.txt (98 vehicles)
#
# C - C2_10_1.txt (96 vehicles)
#
# R - R1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 234: Mean=-0.36 +/- 0.19 | [-1.03, -0.16] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 235/250
# ================================================================================
# Training: ['R:R1_10_1.txt', 'RC:RC2_10_1.txt', 'C:C2_10_1.txt']
#
# R - R1_10_1.txt (98 vehicles)
#
# RC - RC2_10_1.txt (97 vehicles)
#
# C - C2_10_1.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 235: Mean=-0.39 +/- 0.17 | [-0.84, -0.19] | eps=0.0100 | 1.8min
#
# ================================================================================
# EPOCH 236/250
# ================================================================================
# Training: ['RC:RC2_10_1.txt', 'C:C1_10_6.txt', 'R:R1_10_4.txt']
#
# RC - RC2_10_1.txt (97 vehicles)
#
# C - C1_10_6.txt (96 vehicles)
#
# R - R1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 236: Mean=-0.36 +/- 0.15 | [-0.81, -0.20] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 237/250
# ================================================================================
# Training: ['R:R2_10_2.txt', 'C:C2_10_3.txt', 'RC:RC2_10_1.txt']
#
# R - R2_10_2.txt (99 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# RC - RC2_10_1.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 237: Mean=-0.38 +/- 0.16 | [-0.79, -0.18] | eps=0.0100 | 1.7min
#
# ================================================================================
# EPOCH 238/250
# ================================================================================
# Training: ['RC:RC1_10_5.txt', 'C:C1_10_2.txt', 'R:R2_10_6.txt']
#
# RC - RC1_10_5.txt (98 vehicles)
#
# C - C1_10_2.txt (96 vehicles)
#
# R - R2_10_6.txt (99 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 238: Mean=-0.35 +/- 0.15 | [-0.79, -0.17] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 239/250
# ================================================================================
# Training: ['RC:RC2_10_2.txt', 'C:C2_10_7.txt', 'R:R2_10_5.txt']
#
# RC - RC2_10_2.txt (97 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# R - R2_10_5.txt (100 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 239: Mean=-0.38 +/- 0.15 | [-0.73, -0.20] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 240/250
# ================================================================================
# Training: ['RC:RC1_10_6.txt', 'R:R1_10_5.txt', 'C:C2_10_7.txt']
#
# RC - RC1_10_6.txt (98 vehicles)
#
# R - R1_10_5.txt (99 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 240: Mean=-0.36 +/- 0.15 | [-0.86, -0.16] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 241/250
# ================================================================================
# Training: ['R:R1_10_10.txt', 'C:C2_10_10.txt', 'RC:RC2_10_6.txt']
#
# R - R1_10_10.txt (99 vehicles)
#
# C - C2_10_10.txt (94 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 241: Mean=-0.36 +/- 0.16 | [-0.78, -0.17] | eps=0.0100 | 1.5min
#
# ================================================================================
# EPOCH 242/250
# ================================================================================
# Training: ['R:R1_10_4.txt', 'C:C1_10_6.txt', 'RC:RC2_10_5.txt']
#
# R - R1_10_4.txt (98 vehicles)
#
# C - C1_10_6.txt (96 vehicles)
#
# RC - RC2_10_5.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 242: Mean=-0.34 +/- 0.15 | [-0.85, -0.22] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 243/250
# ================================================================================
# Training: ['RC:RC2_10_6.txt', 'C:C2_10_7.txt', 'R:R1_10_4.txt']
#
# RC - RC2_10_6.txt (97 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# R - R1_10_4.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 243: Mean=-0.37 +/- 0.15 | [-0.76, -0.17] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 244/250
# ================================================================================
# Training: ['R:R1_10_9.txt', 'RC:RC2_10_4.txt', 'C:C2_10_7.txt']
#
# R - R1_10_9.txt (99 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# C - C2_10_7.txt (95 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 244: Mean=-0.35 +/- 0.15 | [-0.86, -0.18] | eps=0.0100 | 1.6min
#
# ================================================================================
# EPOCH 245/250
# ================================================================================
# Training: ['R:R1_10_4.txt', 'C:C2_10_3.txt', 'RC:RC2_10_7.txt']
#
# R - R1_10_4.txt (98 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 245: Mean=-0.36 +/- 0.16 | [-0.84, -0.18] | eps=0.0100 | 1.5min
#
# ================================================================================
# EPOCH 246/250
# ================================================================================
# Training: ['C:C2_10_7.txt', 'R:R1_10_9.txt', 'RC:RC2_10_7.txt']
#
# C - C2_10_7.txt (95 vehicles)
#
# R - R1_10_9.txt (99 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 246: Mean=-0.39 +/- 0.17 | [-0.81, -0.17] | eps=0.0100 | 1.3min
#
# ================================================================================
# EPOCH 247/250
# ================================================================================
# Training: ['R:R2_10_8.txt', 'RC:RC2_10_7.txt', 'C:C2_10_5.txt']
#
# R - R2_10_8.txt (99 vehicles)
#
# RC - RC2_10_7.txt (98 vehicles)
#
# C - C2_10_5.txt (96 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 247: Mean=-0.39 +/- 0.16 | [-0.93, -0.14] | eps=0.0100 | 1.3min
#
# ================================================================================
# EPOCH 248/250
# ================================================================================
# Training: ['R:R1_10_1.txt', 'RC:RC2_10_4.txt', 'C:C2_10_3.txt']
#
# R - R1_10_1.txt (98 vehicles)
#
# RC - RC2_10_4.txt (98 vehicles)
#
# C - C2_10_3.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 248: Mean=-0.35 +/- 0.16 | [-0.84, -0.18] | eps=0.0100 | 1.3min
#
# ================================================================================
# EPOCH 249/250
# ================================================================================
# Training: ['R:R1_10_2.txt', 'C:C2_10_2.txt', 'RC:RC1_10_6.txt']
#
# R - R1_10_2.txt (97 vehicles)
#
# C - C2_10_2.txt (98 vehicles)
#
# RC - RC1_10_6.txt (98 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 249: Mean=-0.36 +/- 0.14 | [-0.79, -0.16] | eps=0.0100 | 1.3min
#
# ================================================================================
# EPOCH 250/250
# ================================================================================
# Training: ['C:C2_10_2.txt', 'R:R1_10_2.txt', 'RC:RC2_10_6.txt']
#
# C - C2_10_2.txt (98 vehicles)
#
# R - R1_10_2.txt (97 vehicles)
#
# RC - RC2_10_6.txt (97 vehicles)
#
# --------------------------------------------------------------------------------
# EPOCH 250: Mean=-0.38 +/- 0.14 | [-0.78, -0.17] | eps=0.0100 | 1.3min
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Episodes: 67867 | Time: 338.1min | Final eps: 0.0100
# ================================================================================
#
# Saving...
# All networks saved with prefix: results\2025-12-18_13-54-23\model_final
#   [OK] Model
#   [OK] Config
#   [OK] Summary
#   [OK] NPZ Data
#
# Saving CSV files...
#   [OK] episode_data.csv (67867 rows)
#   [OK] losses_data.csv (88134 rows)
#   [OK] epoch_data.csv (250 rows)
#   [OK] training_summary.csv (67867 rows)
#
# ================================================================================
# GENERATING PLOTS
# ================================================================================
# Creating: 1_reward_by_episode.png ...
#   [OK] Saved
# Creating: 2_reward_by_epoch.png ...
#   [OK] Saved
# Creating: 3_station_loss.png ...
#   [OK] Saved
# Creating: 4_portion_loss.png ...
#   [OK] Saved
# Creating: 5_epsilon_decay.png ...
#   [OK] Saved
# --------------------------------------------------------------------------------
# Saved 5/5 plots to: results\2025-12-18_13-54-23
# ================================================================================
#
#
# ================================================================================
# SAVED FILES:
# ================================================================================
#   Model:     model_final/
#   Config:    config.txt
#   Summary:   summary.txt
#   NPZ Data:  training_data.npz
#   CSV Files:
#              - episode_data.csv
#              - losses_data.csv
#              - epoch_data.csv
#              - training_summary.csv
#   Plots:     5 PNG files
# ================================================================================
#
#
# ================================================================================
# DONE! Results: results\2025-12-18_13-54-23
#   Plots: ['1_reward_by_episode.png', '2_reward_by_epoch.png', '3_station_loss.png', '4_portion_loss.png', '5_epsilon_decay.png']
# ================================================================================
